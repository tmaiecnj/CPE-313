# %% [markdown]
# # **CPE 313 - Advanced Machine Learning and Deep Learning**

# %% [markdown]
# # Prelim Skill Exam

# %% [markdown]
# **Name:** Canja, Tricha Maie
#
# **Section:** CPE32S8
#
# **Date Submitted:** March 14, 2024
#
# **Instructor:** Engr. Roman Richard

# %% [markdown]
# ## Resources:

# %% [markdown]
# https://www.kaggle.com/datasets/nih-chest-xrays/data

# %% [markdown]
# ## Procedures:

# %% [markdown]
# #### Packages

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

import os
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

from itertools import chain
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from __future__ import print_function

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam, SGD, RMSprop

from tensorflow.keras.applications import EfficientNetB0


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Preprocessing

# %%
## Entire list of X-Ray

xray_df = pd.read_csv('C:/Users/trich/OneDrive/Documents/Data/Data_Entry_2017.csv')

# %%
## Find .png files in directory

image_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('C:/Users/trich/OneDrive/Documents/', 'Data', 'images*', '*', '*.png'))}  

print('Scans found:', len(image_paths), ', Total Headers', xray_df.shape[0])
# Out:
# Scans found: 112120 , Total Headers 112120

# %%
xray_df['path'] = xray_df['Image Index'].map(image_paths.get)

# %%
## Check for null values

xray_df.isna().sum()
# Out:
# Image Index                         0
# Finding Labels                      0
# Follow-up #                         0
# Patient ID                          0
# Patient Age                         0
# Patient Gender                      0
# View Position                       0
# OriginalImage[Width                 0
# Height]                             0
# OriginalImagePixelSpacing[x         0
# y]                                  0
# Unnamed: 11                    112120
# path                                0
# dtype: int64

# %%
## Drop the 'Unnamed: 11'
## because empty values

xray_df.drop('Unnamed: 11', axis=1, inplace=True)

# %%
## Check shape of xray_df

xray_df.shape
# Out:
# (112120, 12)

# %%
## Find all data with label of 'No Finding'
## Removes the 'No Findings'

xray_df['Finding Labels'] = xray_df['Finding Labels'].map(lambda x: x.replace('No Finding', ''))

# %%
## Extracting all unique labels
## labels that seperated by '|'

all_labels = np.unique(list(chain(*xray_df['Finding Labels'].map(lambda x: x.split('|')).tolist())))

all_labels = [x for x in all_labels if len(x)>0]

print('All Labels ({}): {}'.format(len(all_labels), all_labels))

for c_label in all_labels:
    if len(c_label)>1: # leave out empty labels
        xray_df[c_label] = xray_df['Finding Labels'].map(lambda finding: 1 if c_label in finding else 0)
# Out:
# All Labels (14): ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Effusion', 'Emphysema', 'Fibrosis', 'Hernia', 'Infiltration', 'Mass', 'Nodule', 'Pleural_Thickening', 'Pneumonia', 'Pneumothorax']

# %%
## Check 3 samples

xray_df.sample(3)
# Out:
#              Image Index         Finding Labels  Follow-up #  Patient ID  \
# 96131   00025290_031.png  Cardiomegaly|Effusion           31       25290
# 44937   00011553_002.png           Infiltration            2       11553
# 105944  00028518_013.png   Atelectasis|Effusion           13       28518
#
#         Patient Age Patient Gender View Position  OriginalImage[Width  \
# 96131            45              F            AP                 3056
# 44937             9              M            AP                 2048
# 105944           48              F            AP                 3056
#
#         Height]  OriginalImagePixelSpacing[x  ...  Effusion Emphysema  \
# 96131      2544                        0.139  ...         1         0
# 44937      2500                        0.168  ...         0         0
# 105944     2544                        0.139  ...         1         0
#
#         Fibrosis  Hernia  Infiltration  Mass  Nodule  Pleural_Thickening  \
# 96131          0       0             0     0       0                   0
# 44937          0       0             1     0       0                   0
# 105944         0       0             0     0       0                   0
#
#         Pneumonia  Pneumothorax
# 96131           0             0
# 44937           0             0
# 105944          0             0
#
# [3 rows x 26 columns]

# %%
## the values in 'Finding Labels' feature

all_labels
# Out:
# ['Atelectasis',
#  'Cardiomegaly',
#  'Consolidation',
#  'Edema',
#  'Effusion',
#  'Emphysema',
#  'Fibrosis',
#  'Hernia',
#  'Infiltration',
#  'Mass',
#  'Nodule',
#  'Pleural_Thickening',
#  'Pneumonia',
#  'Pneumothorax']

# %%
## This is for checking the disease in the dataset that are fewer than 1000
## Which means that we will only get with the common diseases

MIN_CASES = 1000

all_labels = [c_label for c_label in all_labels if xray_df[c_label].sum() > MIN_CASES]

print('Clean Labels ({})'.format(len(all_labels)))

for c_label in all_labels:
    print(c_label, '-', int(xray_df[c_label].sum()))
# Out:
# Clean Labels (13)
# Atelectasis - 11559
# Cardiomegaly - 2776
# Consolidation - 4667
# Edema - 2303
# Effusion - 13317
# Emphysema - 2516
# Fibrosis - 1686
# Infiltration - 19894
# Mass - 5782
# Nodule - 6331
# Pleural_Thickening - 3385
# Pneumonia - 1431
# Pneumothorax - 5302

# %%
## adjust the weight of the samples
## the more labels findings have higher weights

sample_weights = xray_df['Finding Labels'].map(lambda x: len(x.split('|')) if len(x)>0 else 0).values + 4e-2
sample_weights /= sample_weights.sum()

xray_df = xray_df.sample(xray_df.shape[0], weights=sample_weights)

# %%
## preparing the train and validation data
## splitting the data

test_xray = 'C:/Users/trich/OneDrive/Documents/Data/test_list.txt'

# %%
# Load the text file containing the training set image indexes
with open(test_xray, 'r') as file:
    test_set_indexes = [line.strip() for line in file]

# Filter the all_images_df DataFrame based on the training set indexes
train_df = xray_df[xray_df['Image Index'].isin(test_set_indexes)]

# Display the training set DataFrame (optional)
print("Test Set DataFrame:")
print(train_df.shape)
# Out:
# Test Set DataFrame:
# (25596, 26)

# %%
trainVal_xray = 'C:/Users/trich/OneDrive/Documents/Data/train_val_list.txt'

# %%
# Load the text file containing the training set image indexes
with open(trainVal_xray, 'r') as file:
    trainVal_set_indexes = [line.strip() for line in file]

# Filter the all_images_df DataFrame based on the training set indexes
valid_df = xray_df[xray_df['Image Index'].isin(trainVal_set_indexes)]

# Display the training set DataFrame (optional)
print("Training Validation Set DataFrame:")
print(valid_df.shape)
# Out:
# Training Validation Set DataFrame:
# (86524, 26)

# %%
## check the train & validation

print('train', train_df.shape[0], 'validation', valid_df.shape[0])
# Out:
# train 25596 validation 86524

# %%
## create a another feature 'disease_vec'
## one-hot encoded

valid_df['disease_vec'] = valid_df.apply(lambda x: x['Finding Labels'].split('|'), axis=1)
train_df['disease_vec'] = train_df.apply(lambda x: x['Finding Labels'].split('|'), axis=1)

# %%
train_df
# Out:
#              Image Index                                Finding Labels  \
# 80366   00019750_022.png                  Edema|Infiltration|Pneumonia
# 107676  00029099_000.png
# 74381   00018253_064.png   Atelectasis|Infiltration|Pleural_Thickening
# 98827   00026132_007.png  Effusion|Emphysema|Infiltration|Pneumothorax
# 15248   00003996_019.png                      Atelectasis|Infiltration
# ...                  ...                                           ...
# 62721   00015530_049.png
# 96798   00025521_001.png
# 92425   00023075_041.png
# 5398    00001437_032.png
# 59955   00014798_014.png
#
#         Follow-up #  Patient ID  Patient Age Patient Gender View Position  \
# 80366            22       19750           61              M            AP
# 107676            0       29099           67              M            AP
# 74381            64       18253           72              F            AP
# 98827             7       26132           29              M            AP
# 15248            19        3996           45              M            PA
# ...             ...         ...          ...            ...           ...
# 62721            49       15530           20              M            AP
# 96798             1       25521           30              F            AP
# 92425            41       23075           31              M            PA
# 5398             32        1437           30              F            AP
# 59955            14       14798           23              M            AP
#
#         OriginalImage[Width  Height]  OriginalImagePixelSpacing[x  ...  \
# 80366                  3056     2544                        0.139  ...
# 107676                 3056     2544                        0.139  ...
# 74381                  3056     2544                        0.139  ...
# 98827                  3056     2544                        0.139  ...
# 15248                  2048     2500                        0.168  ...
# ...                     ...      ...                          ...  ...
# 62721                  3056     2544                        0.139  ...
# 96798                  3056     2544                        0.139  ...
# 92425                  2908     2889                        0.143  ...
# 5398                   3056     2544                        0.139  ...
# 59955                  2500     2048                        0.168  ...
#
#         Emphysema Fibrosis  Hernia  Infiltration  Mass  Nodule  \
# 80366           0        0       0             1     0       0
# 107676          0        0       0             0     0       0
# 74381           0        0       0             1     0       0
# 98827           1        0       0             1     0       0
# 15248           0        0       0             1     0       0
# ...           ...      ...     ...           ...   ...     ...
# 62721           0        0       0             0     0       0
# 96798           0        0       0             0     0       0
# 92425           0        0       0             0     0       0
# 5398            0        0       0             0     0       0
# 59955           0        0       0             0     0       0
#
#         Pleural_Thickening  Pneumonia  Pneumothorax  \
# 80366                    0          1             0
# 107676                   0          0             0
# 74381                    1          0             0
# 98827                    0          0             1
# 15248                    0          0             0
# ...                    ...        ...           ...
# 62721                    0          0             0
# 96798                    0          0             0
# 92425                    0          0             0
# 5398                     0          0             0
# 59955                    0          0             0
#
#                                               disease_vec
# 80366                    [Edema, Infiltration, Pneumonia]
# 107676                                                 []
# 74381     [Atelectasis, Infiltration, Pleural_Thickening]
# 98827   [Effusion, Emphysema, Infiltration, Pneumothorax]
# 15248                         [Atelectasis, Infiltration]
# ...                                                   ...
# 62721                                                  []
# 96798                                                  []
# 92425                                                  []
# 5398                                                   []
# 59955                                                  []
#
# [25596 rows x 27 columns]

# %% [markdown]
# #### Training preparation

# %%
##

IMG_SIZE = (128, 128)

core_idg = ImageDataGenerator(samplewise_center=True, 
                              samplewise_std_normalization=True, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range= 0.05, 
                              width_shift_range=0.1, 
                              rotation_range=5, 
                              shear_range = 0.1,
                              fill_mode = 'reflect',
                              zoom_range=0.15
                             )

# %%
train_generator = core_idg.flow_from_dataframe(dataframe=train_df, 
                                               directory=None,
                                               x_col = 'path',
                                               y_col = 'disease_vec', 
                                               class_mode = 'categorical',
                                               color_mode = 'grayscale',
                                               classes = all_labels,
                                               target_size = IMG_SIZE,
                                               batch_size = 32
                                              )
# Out:
# Found 15690 validated image filenames belonging to 13 classes.

# %%
##

validation_generator = core_idg.flow_from_dataframe(valid_df,
                                                    x_col = 'path',
                                                    y_col = 'disease_vec',
                                                    class_mode='categorical',
                                                    color_mode = 'grayscale',
                                                    classes = all_labels,
                                                    target_size=IMG_SIZE,
                                                    batch_size=128,
                                                   )
# Out:
# Found 35959 validated image filenames belonging to 13 classes.

# %%
##

X_test, y_test = next(core_idg.flow_from_dataframe(dataframe=valid_df,
                                                   directory=None,
                                                   x_col = 'path',
                                                   y_col = 'disease_vec',
                                                   class_mode = 'categorical',
                                                   color_mode = 'grayscale',
                                                   classes = all_labels,
                                                   target_size = IMG_SIZE,
                                                   batch_size = 1024))
# Out:
# Found 35959 validated image filenames belonging to 13 classes.

# %%
##

t_x, t_y = next(train_generator)

fig, m_axs = plt.subplots(2, 2, figsize = (8, 8))

for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -1.5, vmax = 1.5)
    c_ax.set_title(', '.join([n_class for n_class, n_score in zip(all_labels, c_y) 
                             if n_score>0.5]))
    c_ax.axis('off')

# %% [markdown]
# ### Activity

# %% [markdown]
# 1. Build and train a CNN model from a scratch.  Apply different regularization techniques and data preprocessing to reduce overfitting.

# %%
##

model1 = Sequential([
    Conv2D(64, (2,2), activation='relu', input_shape=(128,128,1), padding='same'),
    MaxPooling2D((2,2)),
    Dropout(0.35),

    Flatten(),
    Dense(32, activation='relu'),
    Dropout((0.6)),
    Dense(16, activation='relu'),
    Dropout((0.6)),
    Dense(len(all_labels), activation='sigmoid')
])

# %%
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 64)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 262144)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │     8,388,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 13)             │           221 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,389,709 (32.00 MB)
#  Trainable params: 8,389,709 (32.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
##

model1.compile(optimizer = 'adam',
               loss = 'binary_crossentropy',
               metrics = ['binary_accuracy'])

# %%
##

history1 = model1.fit(train_generator,
                      steps_per_epoch=100,
                      validation_data = (X_test, y_test), 
                      epochs = 1)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - binary_accuracy: 0.8085 - loss: 0.8189 - val_binary_accuracy: 0.8830 - val_loss: 0.6528

# %%
##

score = model1.evaluate(X_test, y_test)

print('Test loss: {:.3f}'.format(score[0]))
print('Test accuracy: {:.3f}'.format(score[1]))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - binary_accuracy: 0.8803 - loss: 0.6531
# Test loss: 0.653
# Test accuracy: 0.883

# %%
##

history1_2 = model1.fit(train_generator,
                        steps_per_epoch=50,
                        validation_data = (X_test, y_test),
                        epochs = 10)

# %%
##

score1_2 = model1.evaluate(X_test, y_test)

print('Test loss: {:.3f}'.format(score1_2[0]))
print('Test accuracy: {:.3f}'.format(score1_2[1]))

# %%
for c_label, s_count in zip(all_labels, 100*np.mean(y_test,0)):
    print('%s: %2.2f%%' % (c_label, s_count))

# %%
pred_Y = model1.predict(X_test,
                        batch_size = 32,
                        verbose = True)

# %% [markdown]
# 2.  Plot the training and validation loss and accuracy. The target accuracy is 85 and above.

# %%
history1_2.history.keys()

# %%
## Function for plotting the loss functions, accuracy and ROC

def plot_loss_accuracy(history):
    
    fig = plt.figure(figsize=(30, 30))
    ax = fig.add_subplot(2, 1, 1)
    ax.plot(history.history["loss"],'r-o', label="Train Loss")
    ax.plot(history.history["val_loss"],'b-o', label="Validation Loss")
    ax.legend(prop={'size': 21})
    ax.set_title('BINARY ENTROPY LOSS')
    ax.grid(True)

    ax = fig.add_subplot(2, 1, 2)
    ax.plot(history.history["binary_accuracy"],'r-x', label="Train Accuracy")
    ax.plot(history.history["val_binary_accuracy"],'b-x', label="Validation Accuracy")
    ax.legend(prop={'size': 21})
    ax.set_title('ACCURACY')
    ax.grid(True)

# %%
def plot_roc(y_test, y_pred, model_name):
    fpr, tpr, thr = roc_curve(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(fpr, tpr, 'k-')
    ax.plot([0, 1], [0, 1], 'k--', linewidth=.5)  # roc curve for random model
    ax.grid(True)
    ax.set(title='ROC Curve for {}'.format(model_name),
           xlim=[-0.01, 1.01], ylim=[-0.01, 1.01], )

# %%
## Training and Validation Accuracy and Loss

plot_loss_accuracy(history1_2)

# %%
plot_roc(y_test, pred_Y, MODEL1_2):

# %% [markdown]
# 3.  Use the assigned pre-trained model and fine-tuned it.

# %%
## Parameters

IMG_SIZE = (224, 224)
batch_size = 64
Num_class = len(all_labels)

# %%
## Pretrained model and Fine-Tuning
## EfficientNetB0

model2 = Sequential([
    EfficientNetB0(include_top=True, weights='imagenet', classes = Num_class, input_shape = (224,224,1)),
    MaxPooling2D((2,2))
    Dropout(0.35),
    
    Conv2D(32, (2,2), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.25),
    Flatten(),
    
    Dense(16, activation='relu'),
    Dropout(0.6),
    Dense(Num_class, activation='sigmoid') 
])

# %%
model2.summary()

# %% [markdown]
# 4. Build and train a CNN model using the modified pretrained model.

# %%
model2.compile(optimizer="adam",
               loss="binary_crossentropy",
               metrics=["binary_accuracy"])

# %%
history2 = model2.fits(train_generator,
                        steps_per_epoch=100,
                        validation_data = (X_test, y_test),
                        epochs = 10)

# %%
##

score2 = model2.evaluate(X_test, y_test)

print('Test loss: {:.3f}'.format(score2[0]))
print('Test accuracy: {:.3f}'.format(score2[1]))

# %%
for c_label, s_count in zip(all_labels, 100*np.mean(y_test,0)):
    print('%s: %2.2f%%' % (c_label, s_count))

# %%
pred_Y = model2.predict(X_test,
                        batch_size = 32,
                        verbose = True)

# %% [markdown]
# 5. Plot the training and validation loss and accuracy. The target accuracy is 95 and above.

# %%
plot_loss_accuracy(history2)

# %%
plot_roc(y_test, pred_Y, MODEL_2):

# %% [markdown]
# 6. Use the classification report, confusion matrix and ROC over AUC metric to evaluate also the performance of the scratch and using pre-trained mode

# %%
## ROC over AUC

#plot_roc(y_test, y_pred, model_name):

# %%
## Classification Report

# %%
## Confusion Matrix

# %% [markdown]
# ## Conclusion
